# %% [markdown]
# # Fraud Detection

# %% [markdown]
# ## Introduction

# %% [markdown]
# The datasets contains transactions made by credit cards in September 2013 by european cardholders. This dataset presents transactions that occurred in two days, where we have 492 frauds out of 284,807 transactions. The dataset is highly unbalanced, the positive class (frauds) account for 0.172% of all transactions.
#
# It contains only numerical input variables which are the result of a PCA transformation. Unfortunately, due to confidentiality issues, we cannot provide the original features and more background information about the data. Features V1, V2, ... V28 are the principal components obtained with PCA, the only features which have not been transformed with PCA are 'Time' and 'Amount'. Feature 'Time' contains the seconds elapsed between each transaction and the first transaction in the dataset. The feature 'Amount' is the transaction Amount, this feature can be used for example-dependant cost-senstive learning. Feature 'Class' is the response variable and it takes value 1 in case of fraud and 0 otherwise.

# %% [markdown]
# ## Code
#
# ### Prereq Setup

# %%
# Import the required libraries

import boto3
import io
import matplotlib.pyplot as plt
import numpy as np 
import os
import pandas as pd 
import datetime

import sagemaker
import sagemaker.amazon.common as smac
from sagemaker.session import get_execution_role
from sagemaker.predictor import csv_serializer, json_deserializer

# %%
# Setup variable input data

s3_bucket = "cc-fraud-demo-source"
s3_source_data_key = "creditcardfraud.zip"
s3_prefix = "sagemaker/fraud-detection-prod/"
local_file_name = "creditcardfraud.zip"
training_instance_type = "ml.m5.large"
training_instance_count = 1
inference_instance_type = "ml.m5.large"
inference_instance_count = 1

# %%
# Setup static variables

s3_training_data_key = "{}training/creditcardfraud.recordio".format(s3_prefix)
s3_training_data_path = os.path.join("s3://", s3_bucket, s3_training_data_key)
role = get_execution_role()
s3 = boto3.resource("s3")
local_file = "/tmp/{}".format(local_file_name)

# %% [markdown]
# ### Data Prep
# Download the source data from S3, unzip if necessary, split into training and test data sets, then upload the training data as protobuf to S3

# %%
# Download the S3 data

try:   
    s3.Bucket(s3_bucket).download_file(s3_source_data_key, local_file)   
except botocore.exceptions.ClientError as e:
    if e.response["Error"]["Code"] == "404":
        print("The object {} does not exist".format(s3_source_data_key))
    elif e.response["Error"]["Code"] == "403":
        print("You do not have permissions to {} ".format(s3_source_data_key))
    else:
        print("Unknown error")
    raise e

# %%
# Unzip the source data if it is zipped

if local_file_name.endswith(".zip") :
    import zipfile
    
    # Create the zip file
    zip_ref = zipfile.ZipFile(local_file, "r")
    
    # Get the first file in the zip
    file_name = zip_ref.namelist()[0]
    
    # Extract that file to tmp
    zip_ref.extract(file_name, "/tmp")
    
    # Close the zip
    zip_ref.close()
    
    # Delete the zip
    os.remove(local_file)
    
    # Reset the local file variable
    local_file = "/tmp/{}".format(file_name)
elif local_file_name.endswith(".gz") :
    import gzip
    # Open the zipped file
    in_file = gzip.open(local_file, "rb")
    
    # Get everything to the left of .gz
    temp_local_file = local_file.rsplit(".gz")[0]
    
    # Create the output file
    out_file = open(temp_local_file)
    
    # Write the uncompressed data to the local file
    out_file.write(in_file.read())
    
    # Close the files
    in_file.close()
    out_file.close()
    
    # Delete the gzip
    os.remove(local_file)
    
    # Reset the local file variable
    local_file = temp_local_file

# %%
# Read, shuffle, and split the data into training and test sets
# We will also remove the last column, the "label", from the data set features
raw_data = pd.read_csv(local_file).values
raw_data_row_count = raw_data.shape[0]

# Use numpy to shuffle the data
np.random.seed(0)
np.random.shuffle(raw_data)

# Use 70% for training, for our 2D array, shape's 
# first item is the row count, the second item is column count
training_row_count = int(raw_data_row_count * 0.7)

# Get the number of rows computed above for training, 0 to the training_row_count
# minus 1, and get # all columns but the last using 0 to "-1", counts backwards from 
# end in the second dimension
training_dataset_features = raw_data[:training_row_count, :-1]
training_dataset_labels = raw_data[:training_row_count, -1]

# Get the remaining rows as from the row count to the end as the
# testing data set
testing_dataset_features = raw_data[training_row_count:, :-1]
testing_dataset_labels = raw_data[training_row_count:, -1]

# Convert the training data set to protobuf and upload to S3
vectors = np.array([t.tolist() for t in training_dataset_features]).astype('float32')
labels = np.array([t.tolist() for t in training_dataset_labels]).astype('float32')

buf = io.BytesIO()
smac.write_numpy_to_dense_tensor(buf, vectors, labels)
buf.seek(0)
s3.Bucket(s3_bucket).Object(s3_training_data_key).upload_fileobj(buf)

# %% [markdown]
# ### Setup Model Training

# %%
# Create a function to create the SageMaker predictor

def train_model(
    s3_training_data_location, 
    s3_model_output_path,
    training_instance_type, 
    training_instance_count, 
    hyperparams,
    job_name
):
    from sagemaker.amazon.amazon_estimator import get_image_uri
    
    # Get the docker container for linear learner training in this region
    container = get_image_uri(boto3.Session().region_name, "linear-learner")
    
    # Create the linear learner estimator
    linear_estimator = sagemaker.estimator.Estimator(container,
                                                    role,
                                                    training_instance_count,
                                                    training_instance_type,
                                                    output_path = s3_model_output_path,
                                                    sagemaker_session = sagemaker.Session()
                                                    )
    
    # Set the hyper params
    linear_estimator.set_hyperparameters(**hyperparams)
    
    # Train the model
    linear_estimator.fit({"train" : s3_training_data_location},
                        job_name = job_name)
    
    return linear_estimator

# %%
def deploy_endpoint(
    linear_estimator,     
    inference_instance_type, 
    inference_instance_count, 
    endpoint_name
):    
    # Deploy the predictor/inference endpoint
    linear_predictor = linear_estimator.deploy(
        inference_instance_count, 
        inference_instance_type,
        endpoint_name = endpoint_name
    )
    linear_predictor.content_type = "text/csv"
    linear_predictor.serializer = csv_serializer
    linear_predictor.deserializer = json_deserializer
    return linear_predictor

# %%
# Create a function to create the SageMaker predictor

def predictor_from_params(
    s3_training_data_location, 
    s3_model_output_path,
    training_instance_type, 
    training_instance_count, 
    hyperparams,
    jobname,
    inference_instance_type, 
    inference_instance_count, 
    endpoint_name
):   
    # Create the linear learner estimator
    linear_estimator = train_model(
        s3_training_data_location, 
        s3_model_output_path,
        training_instance_type,
        training_instance_count,
        hyperparams,
        jobname
    )
    
    # Deploy the predictor/inference endpoint
    linear_predictor = deploy_endpoint(linear_estimator, inference_instance_type, inference_instance_count, endpoint_name)
    
    return linear_predictor

# %%
# Create a function to run inference testing

def test_inference(
    linear_predictor, 
    test_features, 
    test_labels, 
    model_name, 
    verbose = True
):
    # Split the test data into 100 batches
    # The inference response deserialization is json with one top level property, "predictions"
    # which is an array and contains objects that have the prediction results
    # "predictions":    [
    #    {
    #        "score": 0.4,
    #        "predicted_label": 0
    #    } 
    # ]
    batches = [linear_predictor.predict(batch)['predictions'] for batch in np.array_split(test_features, 100)]
    
    # Now get the predicted label values
    test_predictions = np.concatenate(
        [np.array([x['predicted_label'] for x in batch]) for batch in batches]
    )
    
    # Calculate true and false positives and negatives
    true_positive = np.logical_and(test_labels, test_predictions).sum()
    false_positive = np.logical_and(1-test_labels, test_predictions).sum()
    true_negative = np.logical_and(1-test_labels, 1 - test_predictions).sum()
    false_negative = np.logical_and(test_labels, 1 - test_predictions).sum()
    
    # calculate binary classification metrics
    recall = true_positive / (true_positive + false_negative)
    precision = true_positive / (true_positive + false_positive)
    accuracy = (true_positive + true_negative) / (true_positive + false_positive + true_negative + false_negative)
    f1 = 2 * precision * recall / (precision + recall)
    
    if verbose:
        print(pd.crosstab(test_labels, test_preds, rownames=['actuals'], colnames=['predictions']))
        print("\n{:<11} {:.3f}".format('Recall:', recall))
        print("{:<11} {:.3f}".format('Precision:', precision))
        print("{:<11} {:.3f}".format('Accuracy:', accuracy))
        print("{:<11} {:.3f}".format('F1:', f1))
        
    return {'TP': true_positive, 'FP': false_positive, 'FN': false_negative, 'TN': true_negative, 'Precision': precision, 'Recall': recall, 'Accuracy': accuracy, 
             'F1': f1, 'Model': model_name}

# %% [markdown]
# ### Train & Deploy the Model

# %%
# Training a binary classifier with default settings: logistic regression
hyperparams = {
    'feature_dim': training_dataset_features.shape[1],
    'predictor_type': 'binary_classifier',
    'binary_classifier_model_selection_criteria': 'precision_at_target_recall', 
    'target_recall': 0.9,
    'positive_example_weight_mult': 'balanced',
    'epochs': 40
}
s3_defaults_output_path = 's3://{}/{}defaults'.format(s3_bucket, s3_prefix)

# Launch training and create the inference endpoint for default predictor
defaults_predictor = predictor_from_params(
    s3_training_data_path, 
    s3_defaults_output_path,
    training_instance_type,
    training_instance_count,
    hyperparams,
    "cc-fraud-prod-" + datetime.datetime.now().strftime("%Y-%m-%d-%H-%M-%S"),
    inference_instance_type,
    inference_instance_count,
    "cc-fraud-prod-" + datetime.datetime.now().strftime("%Y-%m-%d-%H-%M-%S")
)
# Out:
# 2019-06-24 19:05:25 Starting - Starting the training job...
# 2019-06-24 19:05:33 Starting - Launching requested ML instances......
# 2019-06-24 19:06:34 Starting - Preparing the instances for training......
# 2019-06-24 19:07:31 Downloading - Downloading input data...
# 2019-06-24 19:08:26 Training - Training image download completed. Training in progress..
# Docker entrypoint called with argument(s): train
# [06/24/2019 19:08:29 INFO 140717281224512] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/resources/default-input.json: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [06/24/2019 19:08:29 INFO 140717281224512] Reading provided configuration from /opt/ml/input/config/hyperparameters.json: {u'predictor_type': u'binary_classifier', u'feature_dim': u'30', u'binary_classifier_model_selection_criteria': u'precision_at_target_recall', u'epochs': u'40', u'positive_example_weight_mult': u'balanced', u'target_recall': u'0.9'}
# [06/24/2019 19:08:29 INFO 140717281224512] Final configuration: {u'loss_insensitivity': u'0.01', u'epochs': u'40', u'feature_dim': u'30', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.9', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'precision_at_target_recall', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'predictor_type': u'binary_classifier', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'balanced', u'l1': u'auto', u'margin': u'1.0'}
# [06/24/2019 19:08:29 WARNING 140717281224512] Loggers have already been setup.
# Process 1 is a worker.
# [06/24/2019 19:08:29 INFO 140717281224512] Using default worker.
# [2019-06-24 19:08:29.750] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 37, "num_examples": 1, "num_bytes": 168000}
# [06/24/2019 19:08:29 INFO 140717281224512] Create Store: local
# [2019-06-24 19:08:29.829] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 77, "num_examples": 11, "num_bytes": 1848000}
# [06/24/2019 19:08:29 INFO 140717281224512] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7ffafcb28dd0>
# [06/24/2019 19:08:29 INFO 140717281224512] Scaling model computed with parameters:
#  {'stdev_weight':
# [4.7194219e+04 2.0129197e+00 1.6956810e+00 1.5737959e+00 1.4211116e+00
#  1.7464067e+00 1.5114434e+00 1.6338520e+00 1.1365393e+00 1.0831476e+00
#  1.0682412e+00 1.0351615e+00 1.0167357e+00 9.9247777e-01 9.7872645e-01
#  9.1369808e-01 8.9051175e-01 8.5879588e-01 8.4427726e-01 8.1105131e-01
#  9.2364085e-01 7.2995019e-01 7.2853160e-01 6.5613961e-01 6.0529310e-01
#  5.2070045e-01 4.8895407e-01 5.0528240e-01 3.7720829e-01 3.4040195e+02]
# <NDArray 30 @cpu(0)>, 'stdev_label': None, 'mean_label': None, 'mean_weight':
# [ 9.4115875e+04 -2.0965910e-02  6.0088383e-03 -6.0604441e-05
#   1.0708881e-03  2.5621313e-03  1.2812650e-02  5.7023759e-03
#   1.3771779e-02  5.0282566e-04 -1.4937603e-02  8.3148787e-03
#   2.4185151e-04 -7.1143378e-03 -6.2215258e-03  1.3560037e-03
#  -3.6126719e-04  4.8326892e-03 -3.6954185e-05  1.1377679e-03
#  -9.4448617e-03 -6.5563759e-03 -1.0307852e-02 -2.0250387e-03
#   3.7677150e-04 -1.4924344e-04  7.9445988e-03  1.2333356e-02
#   2.3962581e-03  8.9079140e+01]
# <NDArray 30 @cpu(0)>}
# [06/24/2019 19:08:29 INFO 140717281224512] nvidia-smi took: 0.0251200199127 secs to identify 0 gpus
# [06/24/2019 19:08:29 INFO 140717281224512] Number of GPUs being used: 0
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 11, "sum": 11.0, "min": 11}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 12, "sum": 12.0, "min": 12}, "Total Records Seen": {"count": 1, "max": 12000, "sum": 12000.0, "min": 12000}, "Max Records Seen Between Resets": {"count": 1, "max": 11000, "sum": 11000.0, "min": 11000}, "Reset Count": {"count": 1, "max": 2, "sum": 2.0, "min": 2}}, "EndTime": 1561403309.98778, "Dimensions": {"Host": "algo-1", "Meta": "init_train_data_iter", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1561403309.987747}
#
# [2019-06-24 19:08:35.471] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 3, "duration": 5483, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4429572541126654, "sum": 0.4429572541126654, "min": 0.4429572541126654}}, "EndTime": 1561403315.472094, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1561403315.472001}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.37577929814017597, "sum": 0.37577929814017597, "min": 0.37577929814017597}}, "EndTime": 1561403315.472221, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1561403315.472203}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.39737335235749055, "sum": 0.39737335235749055, "min": 0.39737335235749055}}, "EndTime": 1561403315.472278, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1561403315.472264}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4277689751093112, "sum": 0.4277689751093112, "min": 0.4277689751093112}}, "EndTime": 1561403315.472326, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1561403315.472314}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4050246850018525, "sum": 0.4050246850018525, "min": 0.4050246850018525}}, "EndTime": 1561403315.472436, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1561403315.472421}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.43049606495766185, "sum": 0.43049606495766185, "min": 0.43049606495766185}}, "EndTime": 1561403315.472486, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1561403315.472472}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4102174079454125, "sum": 0.4102174079454125, "min": 0.4102174079454125}}, "EndTime": 1561403315.47258, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1561403315.472545}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4261759479465197, "sum": 0.4261759479465197, "min": 0.4261759479465197}}, "EndTime": 1561403315.472633, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1561403315.472619}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3902115892189831, "sum": 0.3902115892189831, "min": 0.3902115892189831}}, "EndTime": 1561403315.472707, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1561403315.472667}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.45053848680659153, "sum": 0.45053848680659153, "min": 0.45053848680659153}}, "EndTime": 1561403315.472799, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1561403315.472785}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4428634941829509, "sum": 0.4428634941829509, "min": 0.4428634941829509}}, "EndTime": 1561403315.472843, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1561403315.472831}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.44393519818483285, "sum": 0.44393519818483285, "min": 0.44393519818483285}}, "EndTime": 1561403315.472891, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1561403315.472878}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3987537403010843, "sum": 0.3987537403010843, "min": 0.3987537403010843}}, "EndTime": 1561403315.472964, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1561403315.472924}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.40642541990807307, "sum": 0.40642541990807307, "min": 0.40642541990807307}}, "EndTime": 1561403315.473092, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1561403315.473078}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3941073636577357, "sum": 0.3941073636577357, "min": 0.3941073636577357}}, "EndTime": 1561403315.473141, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1561403315.473128}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4064912524582753, "sum": 0.4064912524582753, "min": 0.4064912524582753}}, "EndTime": 1561403315.473187, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1561403315.473175}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4816090896069704, "sum": 0.4816090896069704, "min": 0.4816090896069704}}, "EndTime": 1561403315.473317, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1561403315.473303}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4238126536613733, "sum": 0.4238126536613733, "min": 0.4238126536613733}}, "EndTime": 1561403315.473385, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1561403315.473372}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4391999156702703, "sum": 0.4391999156702703, "min": 0.4391999156702703}}, "EndTime": 1561403315.473494, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1561403315.473479}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4435035143138176, "sum": 0.4435035143138176, "min": 0.4435035143138176}}, "EndTime": 1561403315.473541, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1561403315.473529}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.41243287984570065, "sum": 0.41243287984570065, "min": 0.41243287984570065}}, "EndTime": 1561403315.47366, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1561403315.473645}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.41160130160537794, "sum": 0.41160130160537794, "min": 0.41160130160537794}}, "EndTime": 1561403315.473712, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1561403315.4737}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4117388085791813, "sum": 0.4117388085791813, "min": 0.4117388085791813}}, "EndTime": 1561403315.473762, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1561403315.473749}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.41248467296811203, "sum": 0.41248467296811203, "min": 0.41248467296811203}}, "EndTime": 1561403315.473823, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1561403315.473794}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.8971699338366638, "sum": 0.8971699338366638, "min": 0.8971699338366638}}, "EndTime": 1561403315.473965, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1561403315.473926}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.8970431944880654, "sum": 0.8970431944880654, "min": 0.8970431944880654}}, "EndTime": 1561403315.474016, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1561403315.474003}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.9163539356634245, "sum": 0.9163539356634245, "min": 0.9163539356634245}}, "EndTime": 1561403315.474064, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1561403315.474052}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.9041241332394394, "sum": 0.9041241332394394, "min": 0.9041241332394394}}, "EndTime": 1561403315.474192, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1561403315.474177}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.983252327770444, "sum": 0.983252327770444, "min": 0.983252327770444}}, "EndTime": 1561403315.474242, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1561403315.474229}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.9731438890006674, "sum": 0.9731438890006674, "min": 0.9731438890006674}}, "EndTime": 1561403315.474339, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1561403315.474277}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.9896999065456678, "sum": 0.9896999065456678, "min": 0.9896999065456678}}, "EndTime": 1561403315.474411, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1561403315.474397}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.9859079421920393, "sum": 0.9859079421920393, "min": 0.9859079421920393}}, "EndTime": 1561403315.474458, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1561403315.474446}
#
# [06/24/2019 19:08:35 INFO 140717281224512] #quality_metric: host=algo-1, epoch=0, train binary_classification_weighted_cross_entropy_objective <loss>=0.442957254113
# [06/24/2019 19:08:35 INFO 140717281224512] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=binary_classification_weighted_cross_entropy_objective, value=0.37577929814
# [06/24/2019 19:08:35 INFO 140717281224512] Epoch 0: Loss improved. Updating best model
# [06/24/2019 19:08:35 INFO 140717281224512] #progress_metric: host=algo-1, completed 2 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Batches Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Records Since Last Reset": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Total Batches Seen": {"count": 1, "max": 212, "sum": 212.0, "min": 212}, "Total Records Seen": {"count": 1, "max": 211364, "sum": 211364.0, "min": 211364}, "Max Records Seen Between Resets": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Reset Count": {"count": 1, "max": 3, "sum": 3.0, "min": 3}}, "EndTime": 1561403315.477969, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1561403309.987975}
#
# [06/24/2019 19:08:35 INFO 140717281224512] #throughput_metric: host=algo-1, train throughput=36313.1391641 records/second
# [2019-06-24 19:08:41.419] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 5, "duration": 5939, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.2921477984711153, "sum": 0.2921477984711153, "min": 0.2921477984711153}}, "EndTime": 1561403321.419677, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1561403321.419563}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.2693447378724065, "sum": 0.2693447378724065, "min": 0.2693447378724065}}, "EndTime": 1561403321.419905, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1561403321.419882}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.2791920361542822, "sum": 0.2791920361542822, "min": 0.2791920361542822}}, "EndTime": 1561403321.420095, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1561403321.420058}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.28432676451409883, "sum": 0.28432676451409883, "min": 0.28432676451409883}}, "EndTime": 1561403321.420246, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1561403321.420225}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.33496494603756083, "sum": 0.33496494603756083, "min": 0.33496494603756083}}, "EndTime": 1561403321.4204, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1561403321.420381}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.37032212323519453, "sum": 0.37032212323519453, "min": 0.37032212323519453}}, "EndTime": 1561403321.420543, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1561403321.420524}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3308690620499041, "sum": 0.3308690620499041, "min": 0.3308690620499041}}, "EndTime": 1561403321.420681, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1561403321.420663}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3733031711865909, "sum": 0.3733031711865909, "min": 0.3733031711865909}}, "EndTime": 1561403321.420835, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1561403321.420816}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.2791007601100596, "sum": 0.2791007601100596, "min": 0.2791007601100596}}, "EndTime": 1561403321.420975, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1561403321.420957}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.2932202476233094, "sum": 0.2932202476233094, "min": 0.2932202476233094}}, "EndTime": 1561403321.42112, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1561403321.421102}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.29213695844333976, "sum": 0.29213695844333976, "min": 0.29213695844333976}}, "EndTime": 1561403321.421263, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1561403321.421245}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.29038060043564995, "sum": 0.29038060043564995, "min": 0.29038060043564995}}, "EndTime": 1561403321.421416, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1561403321.421397}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.33282200816168855, "sum": 0.33282200816168855, "min": 0.33282200816168855}}, "EndTime": 1561403321.421562, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1561403321.421544}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3697210019461474, "sum": 0.3697210019461474, "min": 0.3697210019461474}}, "EndTime": 1561403321.421722, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1561403321.421703}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.33547471131751283, "sum": 0.33547471131751283, "min": 0.33547471131751283}}, "EndTime": 1561403321.421868, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1561403321.421849}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3709609437492026, "sum": 0.3709609437492026, "min": 0.3709609437492026}}, "EndTime": 1561403321.42201, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1561403321.421992}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3744950140564885, "sum": 0.3744950140564885, "min": 0.3744950140564885}}, "EndTime": 1561403321.422165, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1561403321.422146}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3724806187692, "sum": 0.3724806187692, "min": 0.3724806187692}}, "EndTime": 1561403321.422317, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1561403321.422298}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3721151756785024, "sum": 0.3721151756785024, "min": 0.3721151756785024}}, "EndTime": 1561403321.422464, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1561403321.422446}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3727419670526706, "sum": 0.3727419670526706, "min": 0.3727419670526706}}, "EndTime": 1561403321.42261, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1561403321.422592}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.39715632382110133, "sum": 0.39715632382110133, "min": 0.39715632382110133}}, "EndTime": 1561403321.422756, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1561403321.422738}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4129681163960366, "sum": 0.4129681163960366, "min": 0.4129681163960366}}, "EndTime": 1561403321.422901, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1561403321.422883}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.39967683399142934, "sum": 0.39967683399142934, "min": 0.39967683399142934}}, "EndTime": 1561403321.423047, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1561403321.423029}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4129195762183798, "sum": 0.4129195762183798, "min": 0.4129195762183798}}, "EndTime": 1561403321.423196, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1561403321.423176}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.8927913904237987, "sum": 0.8927913904237987, "min": 0.8927913904237987}}, "EndTime": 1561403321.423346, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1561403321.423327}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.8948884366289455, "sum": 0.8948884366289455, "min": 0.8948884366289455}}, "EndTime": 1561403321.423494, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1561403321.423476}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.8923227934717533, "sum": 0.8923227934717533, "min": 0.8923227934717533}}, "EndTime": 1561403321.423648, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1561403321.423629}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.8943540784366166, "sum": 0.8943540784366166, "min": 0.8943540784366166}}, "EndTime": 1561403321.423804, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1561403321.423785}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.9718443757637062, "sum": 0.9718443757637062, "min": 0.9718443757637062}}, "EndTime": 1561403321.423953, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1561403321.423935}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.9638324246813903, "sum": 0.9638324246813903, "min": 0.9638324246813903}}, "EndTime": 1561403321.424101, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1561403321.424082}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.9720205597230538, "sum": 0.9720205597230538, "min": 0.9720205597230538}}, "EndTime": 1561403321.424248, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1561403321.424229}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.9664163158167547, "sum": 0.9664163158167547, "min": 0.9664163158167547}}, "EndTime": 1561403321.424395, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1561403321.424377}
#
# [06/24/2019 19:08:41 INFO 140717281224512] #quality_metric: host=algo-1, epoch=1, train binary_classification_weighted_cross_entropy_objective <loss>=0.292147798471
# [06/24/2019 19:08:41 INFO 140717281224512] #early_stopping_criteria_metric: host=algo-1, epoch=1, criteria=binary_classification_weighted_cross_entropy_objective, value=0.269344737872
# [06/24/2019 19:08:41 INFO 140717281224512] Epoch 1: Loss improved. Updating best model
# [06/24/2019 19:08:41 INFO 140717281224512] #progress_metric: host=algo-1, completed 5 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Batches Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Records Since Last Reset": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Total Batches Seen": {"count": 1, "max": 412, "sum": 412.0, "min": 412}, "Total Records Seen": {"count": 1, "max": 410728, "sum": 410728.0, "min": 410728}, "Max Records Seen Between Resets": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Reset Count": {"count": 1, "max": 4, "sum": 4.0, "min": 4}}, "EndTime": 1561403321.428796, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1561403315.479783}
#
# [06/24/2019 19:08:41 INFO 140717281224512] #throughput_metric: host=algo-1, train throughput=33511.3763932 records/second
# [2019-06-24 19:08:47.264] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 7, "duration": 5832, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.266453914239778, "sum": 0.266453914239778, "min": 0.266453914239778}}, "EndTime": 1561403327.26449, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1561403327.264379}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.25232003197598096, "sum": 0.25232003197598096, "min": 0.25232003197598096}}, "EndTime": 1561403327.264576, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1561403327.26456}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.25930291479676215, "sum": 0.25930291479676215, "min": 0.25930291479676215}}, "EndTime": 1561403327.264825, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1561403327.264802}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.2604919832699263, "sum": 0.2604919832699263, "min": 0.2604919832699263}}, "EndTime": 1561403327.264893, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1561403327.264877}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3080191137994354, "sum": 0.3080191137994354, "min": 0.3080191137994354}}, "EndTime": 1561403327.265038, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1561403327.265023}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3693255433892485, "sum": 0.3693255433892485, "min": 0.3693255433892485}}, "EndTime": 1561403327.265083, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1561403327.265071}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3080750028140581, "sum": 0.3080750028140581, "min": 0.3080750028140581}}, "EndTime": 1561403327.265139, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1561403327.265126}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3694800295805811, "sum": 0.3694800295805811, "min": 0.3694800295805811}}, "EndTime": 1561403327.265188, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1561403327.265176}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.26035717083341514, "sum": 0.26035717083341514, "min": 0.26035717083341514}}, "EndTime": 1561403327.265433, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1561403327.265413}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.26642608113504535, "sum": 0.26642608113504535, "min": 0.26642608113504535}}, "EndTime": 1561403327.265496, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1561403327.265482}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.2678363090400121, "sum": 0.2678363090400121, "min": 0.2678363090400121}}, "EndTime": 1561403327.265545, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1561403327.265533}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.26467212170931564, "sum": 0.26467212170931564, "min": 0.26467212170931564}}, "EndTime": 1561403327.265693, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1561403327.265675}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3138556896286394, "sum": 0.3138556896286394, "min": 0.3138556896286394}}, "EndTime": 1561403327.265755, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1561403327.265734}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.37690201124833456, "sum": 0.37690201124833456, "min": 0.37690201124833456}}, "EndTime": 1561403327.265805, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1561403327.265792}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3151628979726053, "sum": 0.3151628979726053, "min": 0.3151628979726053}}, "EndTime": 1561403327.265852, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1561403327.265839}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.37748920663038094, "sum": 0.37748920663038094, "min": 0.37748920663038094}}, "EndTime": 1561403327.266035, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1561403327.266017}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3703979607203498, "sum": 0.3703979607203498, "min": 0.3703979607203498}}, "EndTime": 1561403327.266097, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1561403327.266073}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.372196794327779, "sum": 0.372196794327779, "min": 0.372196794327779}}, "EndTime": 1561403327.266205, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1561403327.266188}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.370384314532256, "sum": 0.370384314532256, "min": 0.370384314532256}}, "EndTime": 1561403327.26631, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1561403327.266296}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.37210454283287775, "sum": 0.37210454283287775, "min": 0.37210454283287775}}, "EndTime": 1561403327.266359, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1561403327.266346}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.39085778509552155, "sum": 0.39085778509552155, "min": 0.39085778509552155}}, "EndTime": 1561403327.266417, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1561403327.266404}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4113058974874679, "sum": 0.4113058974874679, "min": 0.4113058974874679}}, "EndTime": 1561403327.266467, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1561403327.266454}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.39196860080508134, "sum": 0.39196860080508134, "min": 0.39196860080508134}}, "EndTime": 1561403327.266594, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1561403327.26658}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.41094209920221836, "sum": 0.41094209920221836, "min": 0.41094209920221836}}, "EndTime": 1561403327.266702, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1561403327.266686}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.8916502185610671, "sum": 0.8916502185610671, "min": 0.8916502185610671}}, "EndTime": 1561403327.266807, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1561403327.266791}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.8947478511944488, "sum": 0.8947478511944488, "min": 0.8947478511944488}}, "EndTime": 1561403327.266855, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1561403327.266842}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.8914581271224286, "sum": 0.8914581271224286, "min": 0.8914581271224286}}, "EndTime": 1561403327.266905, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1561403327.266892}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.8944943425930925, "sum": 0.8944943425930925, "min": 0.8944943425930925}}, "EndTime": 1561403327.266952, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1561403327.266939}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.978191915540839, "sum": 0.978191915540839, "min": 0.978191915540839}}, "EndTime": 1561403327.266997, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1561403327.266985}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.964056359985965, "sum": 0.964056359985965, "min": 0.964056359985965}}, "EndTime": 1561403327.267044, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1561403327.267031}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.9798433577187696, "sum": 0.9798433577187696, "min": 0.9798433577187696}}, "EndTime": 1561403327.267091, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1561403327.267078}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.9672219709080069, "sum": 0.9672219709080069, "min": 0.9672219709080069}}, "EndTime": 1561403327.267137, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1561403327.267125}
#
# [06/24/2019 19:08:47 INFO 140717281224512] #quality_metric: host=algo-1, epoch=2, train binary_classification_weighted_cross_entropy_objective <loss>=0.26645391424
# [06/24/2019 19:08:47 INFO 140717281224512] #early_stopping_criteria_metric: host=algo-1, epoch=2, criteria=binary_classification_weighted_cross_entropy_objective, value=0.252320031976
# [06/24/2019 19:08:47 INFO 140717281224512] Epoch 2: Loss improved. Updating best model
# [06/24/2019 19:08:47 INFO 140717281224512] #progress_metric: host=algo-1, completed 7 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Batches Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Records Since Last Reset": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Total Batches Seen": {"count": 1, "max": 612, "sum": 612.0, "min": 612}, "Total Records Seen": {"count": 1, "max": 610092, "sum": 610092.0, "min": 610092}, "Max Records Seen Between Resets": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Reset Count": {"count": 1, "max": 5, "sum": 5.0, "min": 5}}, "EndTime": 1561403327.269859, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1561403321.431294}
#
# [06/24/2019 19:08:47 INFO 140717281224512] #throughput_metric: host=algo-1, train throughput=34145.2661589 records/second
# [2019-06-24 19:08:52.680] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 9, "duration": 5408, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.2547896152668862, "sum": 0.2547896152668862, "min": 0.2547896152668862}}, "EndTime": 1561403332.680697, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1561403332.680608}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.24431480334871378, "sum": 0.24431480334871378, "min": 0.24431480334871378}}, "EndTime": 1561403332.680777, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1561403332.680761}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.24987040192877227, "sum": 0.24987040192877227, "min": 0.24987040192877227}}, "EndTime": 1561403332.680826, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1561403332.680814}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.24970522672566936, "sum": 0.24970522672566936, "min": 0.24970522672566936}}, "EndTime": 1561403332.680869, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1561403332.680858}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.2934199993382746, "sum": 0.2934199993382746, "min": 0.2934199993382746}}, "EndTime": 1561403332.680909, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1561403332.680899}
#
# ...
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.22849704773102572, "sum": 0.22849704773102572, "min": 0.22849704773102572}}, "EndTime": 1561403479.416274, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 30}, "StartTime": 1561403479.416262}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.2225065709406407, "sum": 0.2225065709406407, "min": 0.2225065709406407}}, "EndTime": 1561403479.416341, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 30}, "StartTime": 1561403479.416327}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.2141827533281029, "sum": 0.2141827533281029, "min": 0.2141827533281029}}, "EndTime": 1561403479.416414, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 30}, "StartTime": 1561403479.416399}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.30421866078592424, "sum": 0.30421866078592424, "min": 0.30421866078592424}}, "EndTime": 1561403479.41646, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 30}, "StartTime": 1561403479.416448}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.21417349191406865, "sum": 0.21417349191406865, "min": 0.21417349191406865}}, "EndTime": 1561403479.416526, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 30}, "StartTime": 1561403479.416513}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.30438732221977194, "sum": 0.30438732221977194, "min": 0.30438732221977194}}, "EndTime": 1561403479.416597, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 30}, "StartTime": 1561403479.416582}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.23178505415413247, "sum": 0.23178505415413247, "min": 0.23178505415413247}}, "EndTime": 1561403479.416643, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 30}, "StartTime": 1561403479.416631}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.229746881954634, "sum": 0.229746881954634, "min": 0.229746881954634}}, "EndTime": 1561403479.416704, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 30}, "StartTime": 1561403479.416676}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.23302011418941632, "sum": 0.23302011418941632, "min": 0.23302011418941632}}, "EndTime": 1561403479.41677, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 30}, "StartTime": 1561403479.416741}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.22974166302704932, "sum": 0.22974166302704932, "min": 0.22974166302704932}}, "EndTime": 1561403479.416824, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 30}, "StartTime": 1561403479.41681}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.22385930369008128, "sum": 0.22385930369008128, "min": 0.22385930369008128}}, "EndTime": 1561403479.416869, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 30}, "StartTime": 1561403479.416858}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3110907344913962, "sum": 0.3110907344913962, "min": 0.3110907344913962}}, "EndTime": 1561403479.416913, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 30}, "StartTime": 1561403479.416901}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.22385968423967983, "sum": 0.22385968423967983, "min": 0.22385968423967983}}, "EndTime": 1561403479.416976, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 30}, "StartTime": 1561403479.416962}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3110903223315675, "sum": 0.3110903223315675, "min": 0.3110903223315675}}, "EndTime": 1561403479.417043, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 30}, "StartTime": 1561403479.417028}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3640479379778531, "sum": 0.3640479379778531, "min": 0.3640479379778531}}, "EndTime": 1561403479.417092, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 30}, "StartTime": 1561403479.41708}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3699408022626561, "sum": 0.3699408022626561, "min": 0.3699408022626561}}, "EndTime": 1561403479.417155, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 30}, "StartTime": 1561403479.417142}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.36435851253337, "sum": 0.36435851253337, "min": 0.36435851253337}}, "EndTime": 1561403479.417223, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 30}, "StartTime": 1561403479.417209}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.36994066263323455, "sum": 0.36994066263323455, "min": 0.36994066263323455}}, "EndTime": 1561403479.417291, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 30}, "StartTime": 1561403479.41726}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.36470519260425666, "sum": 0.36470519260425666, "min": 0.36470519260425666}}, "EndTime": 1561403479.417341, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 30}, "StartTime": 1561403479.417329}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.38670209675697825, "sum": 0.38670209675697825, "min": 0.38670209675697825}}, "EndTime": 1561403479.417403, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 30}, "StartTime": 1561403479.417391}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3647052168342935, "sum": 0.3647052168342935, "min": 0.3647052168342935}}, "EndTime": 1561403479.417466, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 30}, "StartTime": 1561403479.417454}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.38670182880804166, "sum": 0.38670182880804166, "min": 0.38670182880804166}}, "EndTime": 1561403479.417535, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 30}, "StartTime": 1561403479.41752}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.8851739182975424, "sum": 0.8851739182975424, "min": 0.8851739182975424}}, "EndTime": 1561403479.417582, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 30}, "StartTime": 1561403479.417571}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.891096773693909, "sum": 0.891096773693909, "min": 0.891096773693909}}, "EndTime": 1561403479.417628, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 30}, "StartTime": 1561403479.417616}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.8857561055092357, "sum": 0.8857561055092357, "min": 0.8857561055092357}}, "EndTime": 1561403479.417686, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 30}, "StartTime": 1561403479.41766}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.8910968707674113, "sum": 0.8910968707674113, "min": 0.8910968707674113}}, "EndTime": 1561403479.417738, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 30}, "StartTime": 1561403479.417726}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.8865078036054295, "sum": 0.8865078036054295, "min": 0.8865078036054295}}, "EndTime": 1561403479.417817, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 30}, "StartTime": 1561403479.417804}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.9715061443079656, "sum": 0.9715061443079656, "min": 0.9715061443079656}}, "EndTime": 1561403479.417885, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 30}, "StartTime": 1561403479.417871}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.8865077658801822, "sum": 0.8865077658801822, "min": 0.8865077658801822}}, "EndTime": 1561403479.417933, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 30}, "StartTime": 1561403479.417921}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.9714938546185518, "sum": 0.9714938546185518, "min": 0.9714938546185518}}, "EndTime": 1561403479.417997, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 30}, "StartTime": 1561403479.417981}
#
# [06/24/2019 19:11:19 INFO 140717281224512] #quality_metric: host=algo-1, epoch=30, train binary_classification_weighted_cross_entropy_objective <loss>=0.230289050232
# [06/24/2019 19:11:19 INFO 140717281224512] #early_stopping_criteria_metric: host=algo-1, epoch=30, criteria=binary_classification_weighted_cross_entropy_objective, value=0.214173491914
# [06/24/2019 19:11:19 INFO 140717281224512] Early stop condition met. Stopping training.
# [06/24/2019 19:11:19 INFO 140717281224512] #progress_metric: host=algo-1, completed 100 % epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Batches Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Records Since Last Reset": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Total Batches Seen": {"count": 1, "max": 6212, "sum": 6212.0, "min": 6212}, "Total Records Seen": {"count": 1, "max": 6192284, "sum": 6192284.0, "min": 6192284}, "Max Records Seen Between Resets": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Reset Count": {"count": 1, "max": 33, "sum": 33.0, "min": 33}}, "EndTime": 1561403479.420408, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 30}, "StartTime": 1561403473.974718}
#
# [06/24/2019 19:11:19 INFO 140717281224512] #throughput_metric: host=algo-1, train throughput=36608.614821 records/second
# [06/24/2019 19:11:19 WARNING 140717281224512] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [06/24/2019 19:11:19 WARNING 140717281224512] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2019-06-24 19:11:19.431] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 65, "duration": 9, "num_examples": 1, "num_bytes": 168000}
# [2019-06-24 19:11:20.227] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 68, "duration": 791, "num_examples": 200, "num_bytes": 33493152}
# [2019-06-24 19:11:21.028] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 70, "duration": 722, "num_examples": 200, "num_bytes": 33493152}
# [06/24/2019 19:11:21 INFO 140717281224512] #train_score (algo-1) : ('binary_classification_weighted_cross_entropy_objective', 0.21347688877100127)
# [06/24/2019 19:11:21 INFO 140717281224512] #train_score (algo-1) : ('binary_classification_accuracy', 0.9886438875624486)
# [06/24/2019 19:11:21 INFO 140717281224512] #train_score (algo-1) : ('binary_f_1.000', 0.2116991643454039)
# [06/24/2019 19:11:21 INFO 140717281224512] #train_score (algo-1) : ('precision', 0.11992110453648915)
# [06/24/2019 19:11:21 INFO 140717281224512] #train_score (algo-1) : ('recall', 0.9020771513353115)
# [06/24/2019 19:11:21 INFO 140717281224512] #quality_metric: host=algo-1, train binary_classification_weighted_cross_entropy_objective <loss>=0.213476888771
# [06/24/2019 19:11:21 INFO 140717281224512] #quality_metric: host=algo-1, train binary_classification_accuracy <score>=0.988643887562
# [06/24/2019 19:11:21 INFO 140717281224512] #quality_metric: host=algo-1, train binary_f_1.000 <score>=0.211699164345
# [06/24/2019 19:11:21 INFO 140717281224512] #quality_metric: host=algo-1, train precision <score>=0.119921104536
# [06/24/2019 19:11:21 INFO 140717281224512] #quality_metric: host=algo-1, train recall <score>=0.902077151335
# [06/24/2019 19:11:21 INFO 140717281224512] Best model found for hyperparameters: {"lr_scheduler_step": 10, "wd": 0.0001, "optimizer": "adam", "lr_scheduler_factor": 0.99, "l1": 0.0, "learning_rate": 0.1, "lr_scheduler_minimum_lr": 0.0001}
# [06/24/2019 19:11:21 INFO 140717281224512] Saved checkpoint to "/tmp/tmpNVWBNA/mx-mod-0000.params"
# [06/24/2019 19:11:21 INFO 140717281224512] Test data is not provided.
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 171424.84498023987, "sum": 171424.84498023987, "min": 171424.84498023987}, "finalize.time": {"count": 1, "max": 1609.5900535583496, "sum": 1609.5900535583496, "min": 1609.5900535583496}, "initialize.time": {"count": 1, "max": 270.08700370788574, "sum": 270.08700370788574, "min": 270.08700370788574}, "check_early_stopping.time": {"count": 31, "max": 1.1889934539794922, "sum": 24.996042251586914, "min": 0.23794174194335938}, "setuptime": {"count": 1, "max": 22.537946701049805, "sum": 22.537946701049805, "min": 22.537946701049805}, "update.time": {"count": 31, "max": 5948.742866516113, "sum": 169372.05481529236, "min": 5356.63104057312}, "epochs": {"count": 1, "max": 40, "sum": 40.0, "min": 40}}, "EndTime": 1561403481.045003, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1561403309.712794}
#
# Billable seconds: 238
# --------------------------------------------------------------------------------------!

# %% [markdown]
# ### Test the Model

# %%
# Evaluate the trained model
predictors = {'Logistic Regression': defaults_predictor }
metrics = {key: test_inference(defaults_predictor, testing_dataset_features, testing_dataset_labels, key, False) for key, predictor in predictors.items()}
pd.set_option('display.float_format', lambda x: '%.3f' % x)
display(pd.DataFrame(list(metrics.values())).loc[:, ['Model', 'Recall', 'Precision', 'Accuracy', 'F1']])
# Out:
#                  Model  Recall  Precision  Accuracy    F1
# 0  Logistic Regression   0.910      0.128     0.989 0.225
